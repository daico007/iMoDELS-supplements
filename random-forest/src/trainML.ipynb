# %%
"""Import neccessary packages"""
import numpy as np
import matplotlib
from matplotlib import pyplot
import json
import pandas as pd
from sklearn import ensemble, linear_model, metrics
import pickle

import atools
from atools_ml.dataio import df_setup
from atools_ml.prep import dimensionality_reduction

from trainML import *

# %%
mixed5050 = pd.read_csv('../../data/raw-data/skimmed-mixed-50-50.csv', index_col=0)
splitted5050_path = '../../data/splitted-data/mixed5050'
everything = pd.read_csv('../../data/raw-data/everything.csv', index_col=0)
splitted_everything_path = '../../data/splitted-data/everything'

splitted5050 = dict()
splitted_everything = dict()

# %%
# for target in ['COF', 'intercept']:
#     splitted5050[target] = split_df(descriptors_df=mixed5050,
#                             test_fraction=0.2,
#                             training_fractions=[0.05, 0.1, 0.2,
#                                                0.3, 0.5, 0.7, 1],
#                             n_bins=6,
#                             target=target,
#                             output_dir=splitted5050_path,
#                             overwrite=True)

#     splitted_everything[target] = split_df(descriptors_df=everything,
#                             test_fraction=0.2,
#                             training_fractions=[0.01, 0.02, 0.03, 0.05, 0.1,
#                                                0.2, 0.3, 0.5, 0.7, 1],
#                             n_bins=6,
#                             target=target,
#                             output_dir=splitted_everything_path,
#                             overwrite=True)

# %%
# """ Train the models"""
# original_csv = pd.read_csv('../../data/raw-data/original-100.csv')
# original_models = dict()
# mixed5050_models = dict()
# everything_models = dict()
# for target in ['COF', 'intercept']:
#     # Train the original models
#     omodel_path = '../models/original/{}'.format(target)
#     original_models[target] = train_rf(data=original_csv,
#                               target=target,
#                               output_path=omodel_path,
#                               overwrite=True)
#     # Train the mixed5050 models
#     for model in splitted5050[target]['train_set']:
#         m5model_path = '../models/mixed5050/{}'.format(model)
#         mixed5050_models[model] = train_rf(data=splitted5050[target]['train_set'][model],
#                                     target=target,
#                                     output_path=m5model_path,
#                                     overwrite=True)
#     # Train the everything model
#     for model in splitted_everything[target]['train_set']:
#         emodel_path = '../models/everything/{}'.format(model)
#         everything_models[model] = train_rf(
#                                     data=splitted_everything[target]['train_set'][model],
#                                     target=target,
#                                     output_path=emodel_path,
#                                     overwrite=True)

# %%
from trainML import *

# %%
original_csv = pd.read_csv('../../data/raw-data/original-100.csv', index_col=0)
test = train_rf(data=original_csv,
                target='COF',
                output_path='./test',
                overwrite=False
                )

# %%
mixed5050 = pd.read_csv('../../data/raw-data/skimmed-mixed-50-50.csv', index_col=0)
splitted5050['COF'] = split_df(descriptors_df=mixed5050,
                        test_fraction=0.2,
                        training_fractions=[0.05, 0.1, 0.2,
                                           0.3, 0.5, 0.7, 1],
                        n_bins=6,
                        target='COF',
                        output_dir=splitted5050_path,
                        overwrite=False)

# %%
splitted5050['COF']['COF_5']
# Out:
#      terminal_group_1 terminal_group_2 terminal_group_3     backbone  frac-1  \
# 37             acetyl            amino          toluene  alkylsilane     0.5
# 76             acetyl      cyclopropyl            amino  alkylsilane     0.5
# 79             acetyl      cyclopropyl      cyclopropyl  alkylsilane     0.5
# 83             acetyl      cyclopropyl         hydroxyl  alkylsilane     0.5
# 85             acetyl      cyclopropyl          methoxy  alkylsilane     0.5
# ...               ...              ...              ...          ...     ...
# 3555          pyrrole          pyrrole         hydroxyl  alkylsilane     0.5
# 3557          pyrrole          pyrrole          methoxy  alkylsilane     0.5
# 3567          pyrrole          toluene            amino  alkylsilane     0.5
# 3576          pyrrole          toluene          methoxy  alkylsilane     0.5
# 3577          pyrrole          toluene           methyl  alkylsilane     0.5
#
#       frac-2       COF    MR-mean   MR-min  asphericity-mean  ...  \
# 37       0.5  0.151387  24.574600  13.2332          0.350526  ...
# 76       0.5  0.152390  13.743950  10.1114          0.234347  ...
# 79       0.5  0.155068  17.887250  17.3765          0.222424  ...
# 83       0.5  0.167208  12.759650   8.1428          0.349820  ...
# 85       0.5  0.152148  15.154750  12.9330          0.433023  ...
# ...      ...       ...        ...      ...               ...  ...
# 3555     0.5  0.164452  19.432825   8.1428          0.331903  ...
# 3557     0.5  0.160212  21.827925  12.9330          0.415106  ...
# 3567     0.5  0.152527  20.417125  10.1114          0.216430  ...
# 3576     0.5  0.157746  21.827925  12.9330          0.415106  ...
# 3577     0.5  0.155488  21.035425  11.3480          0.151057  ...
#
#       vsa-fppos-mean  vsa-fppos-min  vsa-hyd-mean  vsa-hyd-min  \
# 37          0.000000            0.0     41.759815    20.811684
# 76          0.000000            0.0     22.998230    13.911787
# 79          0.000000            0.0     34.271221    32.084674
# 83          0.040452            0.0     21.617451    11.150228
# 85          0.000000            0.0     27.192565    22.300456
# ...              ...            ...           ...          ...
# 3555        0.040452            0.0     31.362088    11.150228
# 3557        0.000000            0.0     36.937202    22.300456
# 3567        0.000000            0.0     32.742867    13.911787
# 3576        0.000000            0.0     36.937202    22.300456
# 3577        0.000000            0.0     36.751141    21.928335
#
#       vsa-polar+-mean  vsa-polar+-min  vsa-polar--mean  vsa-polar--min  \
# 37             0.0000             0.0         2.628563        0.000000
# 76             0.0000             0.0         4.058493        2.397269
# 79             0.0000             0.0         1.198634        0.000000
# 83             0.7156             0.0         3.753038        2.397269
# 85             0.0000             0.0         3.567066        2.397269
# ...               ...             ...              ...             ...
# 3555           0.7156             0.0         3.798655        2.488501
# 3557           0.0000             0.0         3.612682        2.488501
# 3567           0.0000             0.0         4.104109        2.488501
# 3576           0.0000             0.0         3.612682        2.488501
# 3577           0.0000             0.0         1.244251        0.000000
#
#       vsa-polar-mean  vsa-polar-min
# 37          0.109713       0.000000
# 76          0.182551       0.073748
# 79          0.036874       0.000000
# 83          0.221722       0.073748
# 85          0.124472       0.073748
# ...              ...            ...
# 3555        0.212244       0.054793
# 3557        0.114995       0.054793
# 3567        0.173073       0.054793
# 3576        0.114995       0.054793
# 3577        0.027396       0.000000
#
# [478 rows x 114 columns]

# %%
splitted5050['COF']['COF_5']
